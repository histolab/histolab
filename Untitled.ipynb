# %%
from src.histolab.data import breast_tissue, aorta_tissue, heart_tissue
from src.histolab.data import breast_tissue_diagnostic_green_pen, breast_tissue_diagnostic_red_pen, breast_tissue_diagnostic_black_pen
from src.histolab.slide import Slide
from PIL import Image

# %% [markdown]
# If example slides are...

# %%
aorta_svs, aorta_path = aorta_tissue()
breast_svs, breast_path = breast_tissue()
heart_svs, heart_path = heart_tissue()

# %%
processed_path = "processed/"

# %%
aorta_slide = Slide(aorta_path, processed_path)
breast_slide = Slide(breast_path, processed_path)
heart_slide = Slide(heart_path, processed_path)

# %%
aorta_slide.dimensions # dimensions at level 0
breast_slide.dimensions
heart_slide.dimensions
# Out:
# (32671, 47076)

# %%
print("tissue | level | dimensions")
print('  0   |', aorta_slide.level_dimensions(level=0))
print('  1   |', aorta_slide.level_dimensions(level=1))
print('  2   |', aorta_slide.level_dimensions(level=2))
# Out:
# tissue | level | dimensions
#   0   | (15374, 17497)
#   1   | (3843, 4374)
#   2   | (1921, 2187)

# %%
aorta_slide.name
breast_slide.name
heart_slide.name
# Out:
# 'JP2K-33003-2'

# %%
aorta_resampled = aorta_slide.resampled_array(scale_factor=64)
breast_resampled = breast_slide.resampled_array()
heart_resampled = heart_slide.resampled_array(scale_factor=128)
Image.fromarray(aorta_resampled)
# Out:
# <PIL.Image.Image image mode=RGB size=240x273 at 0x12459F9D0>

# %%
Image.fromarray(breast_resampled)
# Out:
# <PIL.Image.Image image mode=RGB size=3030x958 at 0x12BA0D610>

# %%
Image.fromarray(heart_resampled)
# Out:
# <PIL.Image.Image image mode=RGB size=255x367 at 0x12B9FB950>

# %%
aorta_slide.save_thumbnail()
breast_slide.save_thumbnail()
heart_slide.save_thumbnail()

# %%
aorta_slide.scaled_image_path()
breast_slide.scaled_image_path()
heart_slide.scaled_image_path()
# Out:
# 'processed/JP2K-33003-2-32x-32671x47076-1020x1471.png'

# %%
heart_slide.show() # does not work in notebook

# %%
heart_slide.thumbnail_path
# Out:
# 'processed/thumbnails/JP2K-33003-2.png'

# %%
heart_slide.biggest_tissue_box_mask
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-d403ed5085bb> in <module>
# ----> 1 heart_slide.biggest_tissue_box_mask
#
# ~/Desktop/histolab/src/histolab/util.py in __get__(self, obj, type)
#     249         value = obj.__dict__.get(self.__name__)
#     250         if value is None:
# --> 251             value = self._fget(obj)
#     252             obj.__dict__[self.__name__] = value
#     253         return value
#
# ~/Desktop/histolab/src/histolab/slide.py in biggest_tissue_box_mask(self)
#     100         regions = self._regions_from_binary_mask(thumb_mask)
#     101         biggest_region = self._biggest_regions(regions, n=1)
# --> 102         biggest_region_coordinates = self._region_coordinates(biggest_region)
#     103         thumb_bbox_mask = polygon_to_mask_array(
#     104             (1000, 1000), biggest_region_coordinates
#
# ...
